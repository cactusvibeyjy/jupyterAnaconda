# %%
from pymongo import MongoClient
import urllib.request
from io import BytesIO
from PIL import Image
from gridfs import GridFSBucket

# %%
db = MongoClient().python_test
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'python_test')

# %%
url = "https://pbs.twimg.com/media/FV2t8k2VUAAUMOi.png"
data = urllib.request.urlopen(url).read()
Image.open(BytesIO(data))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=784x649 at 0x20F5FC3D250>

# %%
bucket = GridFSBucket(db)
bucket

# %%
grid_in = bucket.open_upload_stream('otter33.jpg',metadata={'contentType': 'image/jpg'})
grid_in

# %%
grid_in.write(data)
grid_in.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-0b1e007f78cf> in <module>
# ----> 1 grid_in.write(data)
#       2 grid_in.close()
#
# ~\anaconda3\lib\site-packages\gridfs\grid_file.py in write(self, data)
#     344         """
#     345         if self._closed:
# --> 346             raise ValueError("cannot write to a closed file")
#     347
#     348         try:
#
# ValueError: cannot write to a closed file

# %%
image_list = list(db.fs.files.find())
image_list
# Out:
# [{'_id': ObjectId('636088efe007769030560825'),
#   'filename': 'test.txt',
#   'chunkSize': 261120,
#   'length': 46,
#   'uploadDate': datetime.datetime(2022, 11, 1, 2, 48, 15, 493000)},
#  {'_id': ObjectId('636088f6e007769030560827'),
#   'filename': 'test.txt',
#   'chunkSize': 261120,
#   'length': 46,
#   'uploadDate': datetime.datetime(2022, 11, 1, 2, 48, 22, 331000)},
#  {'_id': ObjectId('636093b9701ee5a68fc71f0e'),
#   'filename': 'maru_smile.jpg',
#   'metadata': {'contentType': 'image/jpg'},
#   'chunkSize': 261120,
#   'length': 18493,
#   'uploadDate': datetime.datetime(2022, 11, 1, 3, 34, 33, 740000)},
#  {'_id': ObjectId('6361c177f75bc483947754c9'),
#   'filename': 'otter33.jpg',
#   'metadata': {'contentType': 'image/jpg'},
#   'chunkSize': 261120,
#   'length': 704965,
#   'uploadDate': datetime.datetime(2022, 11, 2, 1, 1, 50, 613000)}]

# %%
real_img = Image.open(BytesIO(data))
real_img.show()
